# %%
import numpy as np
from bs4 import BeautifulSoup
import requests
import time
from datetime import datetime

# %%
years = range(2006, 2016)

resort = ['washington/mt-baker', 'british-columbia/whistler-blackcomb']
url = 'http://www.onthesnow.com/{0}/historical-snowfall.html?&q=snow&v=list&y={1}'

data = {}
for loc in [0, 1]:
    snowdata = []

    for y in years:
        r = requests.get(url.format(resort[loc], y))
        
        soup = BeautifulSoup(r.content, 'lxml')
        
        snowfall = soup.find('table', {'class': 'snowfall'})

        for row in snowfall('tr')[1:]:
            snowdata.append([x.contents[0] for x in row('td')])
            
    data[loc] = snowdata

# %%
def convert_date(string):
    return datetime.fromtimestamp(time.mktime(time.strptime(string, "%b  %d, %Y")))

def in_to_int(string):
    return int(string.replace(" in.",""))

# %%
data[0][0]
# Out:
# [u'Jan  6, 2006', u'5 in.', u'5 in.', u'75 in.']

# %%
for day in data[0]:
    print [convert_date(day[0])] + [in_to_int(string) for string in day[1:4]]
# Out:
# [datetime.datetime(2006, 1, 6, 0, 0), 5, 5, 75]
# [datetime.datetime(2006, 1, 17, 0, 0), 2, 7, 0]
# [datetime.datetime(2006, 1, 18, 0, 0), 2, 9, 135]
# [datetime.datetime(2006, 1, 26, 0, 0), 8, 17, 135]
# [datetime.datetime(2006, 2, 3, 0, 0), 7, 24, 186]
# [datetime.datetime(2006, 3, 1, 0, 0), 6, 30, 188]
# [datetime.datetime(2006, 11, 13, 0, 0), 14, 44, 59]
# [datetime.datetime(2006, 11, 14, 0, 0), 10, 54, 68]
# [datetime.datetime(2006, 11, 15, 0, 0), 6, 60, 68]
# [datetime.datetime(2006, 11, 17, 0, 0), 3, 63, 68]
# [datetime.datetime(2006, 11, 20, 0, 0), 4, 67, 68]
# [datetime.datetime(2006, 11, 21, 0, 0), 15, 82, 68]
# [datetime.datetime(2006, 11, 22, 0, 0), 16, 98, 68]
# [datetime.datetime(2006, 11, 23, 0, 0), 15, 113, 72]
# [datetime.datetime(2006, 11, 24, 0, 0), 16, 129, 76]
# [datetime.datetime(2006, 11, 26, 0, 0), 20, 149, 116]
# [datetime.datetime(2006, 11, 27, 0, 0), 26, 175, 116]
# [datetime.datetime(2006, 11, 30, 0, 0), 1, 176, 125]
# [datetime.datetime(2006, 12, 1, 0, 0), 2, 178, 117]
# [datetime.datetime(2006, 12, 4, 0, 0), 1, 179, 105]
# [datetime.datetime(2006, 12, 5, 0, 0), 5, 184, 98]
# [datetime.datetime(2006, 12, 9, 0, 0), 1, 185, 87]
# [datetime.datetime(2006, 12, 10, 0, 0), 1, 186, 87]
# [datetime.datetime(2006, 12, 11, 0, 0), 5, 191, 85]
# [datetime.datetime(2006, 12, 12, 0, 0), 5, 196, 85]
# [datetime.datetime(2006, 12, 13, 0, 0), 13, 209, 85]
# [datetime.datetime(2006, 12, 15, 0, 0), 4, 213, 85]
# [datetime.datetime(2006, 12, 17, 0, 0), 4, 217, 100]
# [datetime.datetime(2006, 12, 19, 0, 0), 1, 218, 100]
# [datetime.datetime(2006, 12, 20, 0, 0), 2, 220, 108]
# [datetime.datetime(2006, 12, 21, 0, 0), 5, 225, 111]
# [datetime.datetime(2006, 12, 22, 0, 0), 12, 237, 120]
# [datetime.datetime(2006, 12, 23, 0, 0), 15, 252, 121]
# [datetime.datetime(2006, 12, 25, 0, 0), 3, 255, 121]
# [datetime.datetime(2006, 12, 26, 0, 0), 14, 269, 135]
# [datetime.datetime(2006, 12, 27, 0, 0), 3, 272, 135]
# [datetime.datetime(2007, 1, 2, 0, 0), 7, 7, 135]
# [datetime.datetime(2007, 1, 3, 0, 0), 3, 10, 133]
# [datetime.datetime(2007, 1, 4, 0, 0), 12, 22, 133]
# [datetime.datetime(2007, 1, 6, 0, 0), 8, 30, 151]
# [datetime.datetime(2007, 1, 7, 0, 0), 14, 44, 156]
# [datetime.datetime(2007, 1, 8, 0, 0), 8, 52, 156]
# [datetime.datetime(2007, 1, 9, 0, 0), 1, 53, 156]
# [datetime.datetime(2007, 1, 10, 0, 0), 5, 58, 156]
# [datetime.datetime(2007, 1, 18, 0, 0), 2, 60, 155]
# [datetime.datetime(2007, 1, 19, 0, 0), 6, 66, 155]
# [datetime.datetime(2007, 1, 20, 0, 0), 12, 78, 160]
# [datetime.datetime(2007, 1, 21, 0, 0), 12, 90, 160]
# [datetime.datetime(2007, 1, 22, 0, 0), 5, 95, 160]
# [datetime.datetime(2007, 1, 23, 0, 0), 4, 99, 160]
# [datetime.datetime(2007, 1, 24, 0, 0), 1, 100, 160]
# [datetime.datetime(2007, 10, 4, 0, 0), 20, 120, 0]
# [datetime.datetime(2007, 11, 12, 0, 0), 4, 124, 0]
# [datetime.datetime(2007, 11, 19, 0, 0), 5, 129, 15]
# [datetime.datetime(2007, 11, 27, 0, 0), 17, 146, 35]
# [datetime.datetime(2007, 11, 29, 0, 0), 2, 148, 34]
# [datetime.datetime(2007, 12, 2, 0, 0), 9, 157, 34]
# [datetime.datetime(2007, 12, 3, 0, 0), 9, 166, 34]
# [datetime.datetime(2007, 12, 5, 0, 0), 2, 168, 30]
# [datetime.datetime(2007, 12, 6, 0, 0), 9, 177, 35]
# [datetime.datetime(2007, 12, 7, 0, 0), 2, 179, 36]
# [datetime.datetime(2007, 12, 10, 0, 0), 2, 181, 36]
# [datetime.datetime(2007, 12, 11, 0, 0), 2, 183, 36]
# [datetime.datetime(2007, 12, 12, 0, 0), 1, 184, 35]
# [datetime.datetime(2007, 12, 13, 0, 0), 1, 185, 35]
# [datetime.datetime(2007, 12, 14, 0, 0), 4, 189, 41]
# [datetime.datetime(2007, 12, 15, 0, 0), 11, 200, 41]
# [datetime.datetime(2007, 12, 16, 0, 0), 16, 216, 41]
# [datetime.datetime(2007, 12, 17, 0, 0), 11, 227, 68]
# [datetime.datetime(2007, 12, 18, 0, 0), 3, 230, 70]
# [datetime.datetime(2007, 12, 19, 0, 0), 8, 238, 83]
# [datetime.datetime(2007, 12, 20, 0, 0), 14, 252, 90]
# [datetime.datetime(2007, 12, 21, 0, 0), 1, 253, 88]
# [datetime.datetime(2007, 12, 22, 0, 0), 3, 256, 88]
# [datetime.datetime(2007, 12, 24, 0, 0), 13, 269, 101]
# [datetime.datetime(2007, 12, 26, 0, 0), 13, 282, 105]
# [datetime.datetime(2007, 12, 27, 0, 0), 3, 285, 105]
# [datetime.datetime(2007, 12, 28, 0, 0), 11, 296, 110]
# [datetime.datetime(2007, 12, 29, 0, 0), 15, 311, 118]
# [datetime.datetime(2007, 12, 30, 0, 0), 6, 317, 124]
# [datetime.datetime(2007, 12, 31, 0, 0), 4, 321, 124]
# [datetime.datetime(2008, 1, 2, 0, 0), 3, 3, 116]
# [datetime.datetime(2008, 1, 3, 0, 0), 8, 11, 116]
# [datetime.datetime(2008, 1, 4, 0, 0), 11, 22, 123]
# [datetime.datetime(2008, 1, 5, 0, 0), 10, 32, 129]
# [datetime.datetime(2008, 1, 6, 0, 0), 5, 37, 134]
# [datetime.datetime(2008, 1, 7, 0, 0), 4, 41, 134]
# [datetime.datetime(2008, 1, 8, 0, 0), 5, 46, 131]
# [datetime.datetime(2008, 1, 9, 0, 0), 10, 56, 135]
# [datetime.datetime(2008, 1, 10, 0, 0), 11, 67, 140]
# [datetime.datetime(2008, 1, 11, 0, 0), 23, 90, 158]
# [datetime.datetime(2008, 1, 12, 0, 0), 5, 95, 158]
# [datetime.datetime(2008, 1, 13, 0, 0), 3, 98, 156]
# [datetime.datetime(2008, 1, 15, 0, 0), 11, 109, 157]
# [datetime.datetime(2008, 1, 20, 0, 0), 5, 114, 147]
# [datetime.datetime(2008, 1, 21, 0, 0), 2, 116, 147]
# [datetime.datetime(2008, 1, 27, 0, 0), 11, 127, 148]
# [datetime.datetime(2008, 1, 29, 0, 0), 7, 134, 148]
# [datetime.datetime(2008, 1, 30, 0, 0), 7, 141, 161]
# [datetime.datetime(2008, 1, 31, 0, 0), 14, 155, 165]
# [datetime.datetime(2008, 2, 1, 0, 0), 16, 171, 175]
# [datetime.datetime(2008, 2, 2, 0, 0), 12, 183, 185]
# [datetime.datetime(2008, 2, 5, 0, 0), 4, 187, 175]
# [datetime.datetime(2008, 2, 7, 0, 0), 14, 201, 184]
# [datetime.datetime(2008, 2, 8, 0, 0), 18, 219, 199]
# [datetime.datetime(2008, 2, 9, 0, 0), 2, 221, 199]
# [datetime.datetime(2008, 2, 10, 0, 0), 3, 224, 191]
# [datetime.datetime(2008, 2, 11, 0, 0), 6, 230, 191]
# [datetime.datetime(2008, 2, 12, 0, 0), 2, 232, 190]
# [datetime.datetime(2008, 2, 13, 0, 0), 5, 237, 188]
# [datetime.datetime(2008, 2, 16, 0, 0), 6, 243, 186]
# [datetime.datetime(2008, 3, 4, 0, 0), 9, 252, 175]
# [datetime.datetime(2008, 3, 8, 0, 0), 8, 260, 174]
# [datetime.datetime(2008, 3, 11, 0, 0), 2, 262, 160]
# [datetime.datetime(2008, 3, 14, 0, 0), 3, 265, 167]
# [datetime.datetime(2008, 3, 15, 0, 0), 6, 271, 169]
# [datetime.datetime(2008, 3, 16, 0, 0), 1, 272, 169]
# [datetime.datetime(2008, 3, 18, 0, 0), 3, 275, 172]
# [datetime.datetime(2008, 3, 21, 0, 0), 8, 283, 181]
# [datetime.datetime(2008, 3, 22, 0, 0), 1, 284, 180]
# [datetime.datetime(2008, 3, 24, 0, 0), 17, 301, 185]
# [datetime.datetime(2008, 3, 27, 0, 0), 10, 311, 199]
# [datetime.datetime(2008, 3, 29, 0, 0), 4, 315, 200]
# [datetime.datetime(2008, 3, 30, 0, 0), 3, 318, 200]
# [datetime.datetime(2008, 3, 31, 0, 0), 2, 320, 198]
# [datetime.datetime(2008, 4, 5, 0, 0), 2, 322, 189]
# [datetime.datetime(2008, 4, 6, 0, 0), 2, 324, 189]
# [datetime.datetime(2008, 4, 18, 0, 0), 5, 329, 191]
# [datetime.datetime(2008, 4, 19, 0, 0), 4, 333, 191]
# [datetime.datetime(2008, 4, 20, 0, 0), 1, 334, 196]
# [datetime.datetime(2008, 4, 25, 0, 0), 7, 341, 195]
# [datetime.datetime(2008, 12, 8, 0, 0), 9, 350, 15]
# [datetime.datetime(2008, 12, 10, 0, 0), 5, 355, 19]
# [datetime.datetime(2008, 12, 11, 0, 0), 5, 360, 19]
# [datetime.datetime(2008, 12, 14, 0, 0), 5, 365, 19]
# [datetime.datetime(2008, 12, 15, 0, 0), 1, 366, 36]
# [datetime.datetime(2008, 12, 17, 0, 0), 3, 369, 37]
# [datetime.datetime(2008, 12, 18, 0, 0), 17, 386, 44]
# [datetime.datetime(2008, 12, 19, 0, 0), 5, 391, 44]
# [datetime.datetime(2008, 12, 21, 0, 0), 5, 396, 44]
# [datetime.datetime(2008, 12, 22, 0, 0), 8, 404, 46]
# [datetime.datetime(2008, 12, 24, 0, 0), 3, 407, 46]
# [datetime.datetime(2008, 12, 25, 0, 0), 20, 427, 60]
# [datetime.datetime(2008, 12, 26, 0, 0), 1, 428, 60]
# [datetime.datetime(2008, 12, 27, 0, 0), 13, 441, 65]
# [datetime.datetime(2008, 12, 28, 0, 0), 12, 453, 73]
# [datetime.datetime(2008, 12, 29, 0, 0), 9, 462, 74]
# [datetime.datetime(2008, 12, 30, 0, 0), 15, 477, 81]
# [datetime.datetime(2008, 12, 31, 0, 0), 6, 483, 81]
# [datetime.datetime(2009, 1, 1, 0, 0), 10, 10, 81]
# [datetime.datetime(2009, 1, 2, 0, 0), 10, 20, 85]
# [datetime.datetime(2009, 1, 3, 0, 0), 2, 22, 82]
# [datetime.datetime(2009, 1, 4, 0, 0), 7, 29, 84]
# [datetime.datetime(2009, 1, 5, 0, 0), 4, 33, 84]
# [datetime.datetime(2009, 1, 6, 0, 0), 12, 45, 84]
# [datetime.datetime(2009, 1, 7, 0, 0), 8, 53, 86]
# [datetime.datetime(2009, 1, 8, 0, 0), 10, 63, 92]
# [datetime.datetime(2009, 1, 9, 0, 0), 7, 70, 98]
# [datetime.datetime(2009, 1, 10, 0, 0), 3, 73, 99]
# [datetime.datetime(2009, 1, 11, 0, 0), 5, 78, 93]
# [datetime.datetime(2009, 1, 25, 0, 0), 1, 79, 77]
# [datetime.datetime(2009, 1, 28, 0, 0), 7, 86, 82]
# [datetime.datetime(2009, 1, 29, 0, 0), 1, 87, 82]
# [datetime.datetime(2009, 1, 31, 0, 0), 2, 89, 86]
# [datetime.datetime(2009, 2, 1, 0, 0), 2, 91, 86]
# [datetime.datetime(2009, 2, 2, 0, 0), 2, 93, 86]
# [datetime.datetime(2009, 2, 6, 0, 0), 1, 94, 82]
# [datetime.datetime(2009, 2, 7, 0, 0), 5, 99, 82]
# [datetime.datetime(2009, 2, 9, 0, 0), 4, 103, 87]
# [datetime.datetime(2009, 2, 11, 0, 0), 5, 108, 90]
# [datetime.datetime(2009, 2, 16, 0, 0), 1, 109, 87]
# [datetime.datetime(2009, 2, 24, 0, 0), 7, 116, 86]
# [datetime.datetime(2009, 2, 25, 0, 0), 11, 127, 86]
# [datetime.datetime(2009, 2, 26, 0, 0), 11, 138, 107]
# [datetime.datetime(2009, 3, 4, 0, 0), 4, 142, 94]
# [datetime.datetime(2009, 3, 5, 0, 0), 10, 152, 99]
# [datetime.datetime(2009, 3, 6, 0, 0), 6, 158, 104]
# [datetime.datetime(2009, 3, 9, 0, 0), 3, 161, 109]
# [datetime.datetime(2009, 3, 10, 0, 0), 5, 166, 112]
# [datetime.datetime(2009, 3, 16, 0, 0), 11, 177, 125]
# [datetime.datetime(2009, 3, 17, 0, 0), 14, 191, 138]
# [datetime.datetime(2009, 3, 18, 0, 0), 22, 213, 143]
# [datetime.datetime(2009, 3, 19, 0, 0), 6, 219, 140]
# [datetime.datetime(2009, 3, 23, 0, 0), 3, 222, 145]
# [datetime.datetime(2009, 3, 24, 0, 0), 2, 224, 135]
# [datetime.datetime(2009, 3, 25, 0, 0), 18, 242, 151]
# [datetime.datetime(2009, 3, 26, 0, 0), 1, 243, 150]
# [datetime.datetime(2009, 3, 27, 0, 0), 2, 245, 145]
# [datetime.datetime(2009, 3, 29, 0, 0), 6, 251, 141]
# [datetime.datetime(2009, 3, 30, 0, 0), 1, 252, 141]
# [datetime.datetime(2009, 4, 3, 0, 0), 7, 259, 149]
# [datetime.datetime(2009, 11, 11, 0, 0), 18, 277, 50]
# [datetime.datetime(2009, 11, 12, 0, 0), 6, 283, 67]
# [datetime.datetime(2009, 11, 16, 0, 0), 7, 290, 67]
# [datetime.datetime(2009, 11, 17, 0, 0), 7, 297, 67]
# [datetime.datetime(2009, 11, 18, 0, 0), 7, 304, 62]
# [datetime.datetime(2009, 11, 20, 0, 0), 8, 312, 75]
# [datetime.datetime(2009, 11, 21, 0, 0), 12, 324, 75]
# [datetime.datetime(2009, 11, 22, 0, 0), 13, 337, 75]
# [datetime.datetime(2009, 11, 23, 0, 0), 11, 348, 87]
# [datetime.datetime(2009, 11, 24, 0, 0), 6, 354, 87]
# [datetime.datetime(2009, 11, 25, 0, 0), 3, 357, 87]
# [datetime.datetime(2009, 11, 29, 0, 0), 2, 359, 67]
# [datetime.datetime(2009, 11, 30, 0, 0), 5, 364, 67]
# [datetime.datetime(2009, 12, 1, 0, 0), 3, 367, 69]
# [datetime.datetime(2009, 12, 16, 0, 0), 4, 371, 67]
# [datetime.datetime(2009, 12, 17, 0, 0), 4, 375, 67]
# [datetime.datetime(2009, 12, 18, 0, 0), 10, 385, 67]
# [datetime.datetime(2009, 12, 24, 0, 0), 6, 391, 67]
# [datetime.datetime(2010, 1, 5, 0, 0), 19, 19, 75]
# [datetime.datetime(2010, 1, 15, 0, 0), 8, 27, 88]
# [datetime.datetime(2010, 1, 18, 0, 0), 2, 29, 105]
# [datetime.datetime(2010, 1, 25, 0, 0), 9, 38, 107]
# [datetime.datetime(2010, 1, 26, 0, 0), 12, 50, 109]
# [datetime.datetime(2010, 2, 3, 0, 0), 2, 52, 107]
# [datetime.datetime(2010, 2, 4, 0, 0), 2, 54, 107]
# [datetime.datetime(2010, 2, 5, 0, 0), 3, 57, 113]
# [datetime.datetime(2010, 2, 6, 0, 0), 3, 60, 113]
# [datetime.datetime(2010, 2, 7, 0, 0), 3, 63, 113]
# [datetime.datetime(2010, 2, 11, 0, 0), 2, 65, 114]
# [datetime.datetime(2010, 2, 12, 0, 0), 3, 68, 114]
# [datetime.datetime(2010, 2, 13, 0, 0), 3, 71, 114]
# [datetime.datetime(2010, 2, 14, 0, 0), 3, 74, 114]
# [datetime.datetime(2010, 2, 16, 0, 0), 2, 76, 123]
# [datetime.datetime(2010, 2, 24, 0, 0), 1, 77, 122]
# [datetime.datetime(2010, 2, 25, 0, 0), 10, 87, 131]
# [datetime.datetime(2010, 2, 26, 0, 0), 5, 92, 135]
# [datetime.datetime(2010, 2, 27, 0, 0), 5, 97, 135]
# [datetime.datetime(2010, 2, 28, 0, 0), 5, 102, 135]
# [datetime.datetime(2010, 3, 9, 0, 0), 4, 106, 132]
# [datetime.datetime(2010, 3, 10, 0, 0), 1, 107, 134]
# [datetime.datetime(2010, 3, 11, 0, 0), 5, 112, 136]
# [datetime.datetime(2010, 3, 12, 0, 0), 15, 127, 151]
# [datetime.datetime(2010, 3, 13, 0, 0), 15, 142, 151]
# [datetime.datetime(2010, 3, 14, 0, 0), 15, 157, 151]
# [datetime.datetime(2010, 3, 15, 0, 0), 2, 159, 159]
# [datetime.datetime(2010, 3, 17, 0, 0), 10, 169, 156]
# [datetime.datetime(2010, 3, 22, 0, 0), 8, 177, 155]
# [datetime.datetime(2010, 3, 23, 0, 0), 1, 178, 148]
# [datetime.datetime(2010, 3, 29, 0, 0), 16, 194, 167]
# [datetime.datetime(2010, 3, 30, 0, 0), 10, 204, 179]
# [datetime.datetime(2010, 3, 31, 0, 0), 7, 211, 179]
# [datetime.datetime(2010, 4, 1, 0, 0), 1, 212, 173]
# [datetime.datetime(2010, 4, 2, 0, 0), 4, 216, 172]
# [datetime.datetime(2010, 4, 3, 0, 0), 4, 220, 172]
# [datetime.datetime(2010, 4, 4, 0, 0), 4, 224, 172]
# [datetime.datetime(2010, 4, 5, 0, 0), 4, 228, 200]
# [datetime.datetime(2010, 4, 6, 0, 0), 6, 234, 195]
# [datetime.datetime(2010, 4, 7, 0, 0), 8, 242, 195]
# [datetime.datetime(2010, 4, 8, 0, 0), 11, 253, 208]
# [datetime.datetime(2010, 4, 25, 0, 0), 5, 258, 173]
# [datetime.datetime(2010, 11, 22, 0, 0), 7, 265, 36]
# [datetime.datetime(2010, 11, 26, 0, 0), 5, 270, 34]
# [datetime.datetime(2010, 12, 9, 0, 0), 12, 282, 61]
# [datetime.datetime(2010, 12, 11, 0, 0), 1, 283, 76]
# [datetime.datetime(2010, 12, 12, 0, 0), 6, 289, 71]
# [datetime.datetime(2010, 12, 19, 0, 0), 11, 300, 79]
# [datetime.datetime(2010, 12, 27, 0, 0), 20, 320, 95]
# [datetime.datetime(2011, 1, 6, 0, 0), 10, 10, 97]
# [datetime.datetime(2011, 1, 8, 0, 0), 8, 18, 107]
# [datetime.datetime(2011, 1, 9, 0, 0), 6, 24, 108]
# [datetime.datetime(2011, 1, 11, 0, 0), 1, 25, 108]
# [datetime.datetime(2011, 1, 15, 0, 0), 5, 30, 119]
# [datetime.datetime(2011, 1, 22, 0, 0), 6, 36, 120]
# [datetime.datetime(2011, 1, 23, 0, 0), 2, 38, 120]
# [datetime.datetime(2011, 1, 29, 0, 0), 3, 41, 112]
# [datetime.datetime(2011, 1, 30, 0, 0), 7, 48, 118]
# [datetime.datetime(2011, 2, 5, 0, 0), 3, 51, 116]
# [datetime.datetime(2011, 2, 6, 0, 0), 1, 52, 116]
# [datetime.datetime(2011, 2, 12, 0, 0), 5, 57, 124]
# [datetime.datetime(2011, 2, 13, 0, 0), 7, 64, 134]
# [datetime.datetime(2011, 2, 24, 0, 0), 4, 68, 159]
# [datetime.datetime(2011, 2, 27, 0, 0), 10, 78, 163]
# [datetime.datetime(2011, 3, 5, 0, 0), 12, 90, 189]
# [datetime.datetime(2011, 3, 6, 0, 0), 2, 92, 187]
# [datetime.datetime(2011, 3, 12, 0, 0), 16, 108, 221]
# [datetime.datetime(2011, 3, 13, 0, 0), 11, 119, 220]
# [datetime.datetime(2011, 3, 20, 0, 0), 1, 120, 136]
# [datetime.datetime(2011, 3, 22, 0, 0), 8, 128, 234]
# [datetime.datetime(2011, 3, 26, 0, 0), 4, 132, 225]
# [datetime.datetime(2011, 3, 27, 0, 0), 1, 133, 222]
# [datetime.datetime(2011, 4, 2, 0, 0), 4, 137, 234]
# [datetime.datetime(2011, 4, 3, 0, 0), 1, 138, 231]
# [datetime.datetime(2011, 4, 10, 0, 0), 1, 139, 241]
# [datetime.datetime(2011, 4, 16, 0, 0), 2, 141, 251]
# [datetime.datetime(2011, 4, 17, 0, 0), 4, 145, 251]
# [datetime.datetime(2011, 11, 18, 0, 0), 28, 173, 45]
# [datetime.datetime(2011, 11, 21, 0, 0), 2, 175, 57]
# [datetime.datetime(2011, 11, 22, 0, 0), 18, 193, 60]
# [datetime.datetime(2011, 11, 23, 0, 0), 18, 211, 60]
# [datetime.datetime(2011, 11, 24, 0, 0), 6, 217, 62]
# [datetime.datetime(2011, 11, 25, 0, 0), 11, 228, 62]
# [datetime.datetime(2011, 11, 26, 0, 0), 3, 231, 68]
# [datetime.datetime(2011, 12, 21, 0, 0), 3, 234, 54]
# [datetime.datetime(2011, 12, 24, 0, 0), 2, 236, 54]
# [datetime.datetime(2011, 12, 26, 0, 0), 4, 240, 58]
# [datetime.datetime(2011, 12, 27, 0, 0), 4, 244, 62]
# [datetime.datetime(2011, 12, 28, 0, 0), 8, 252, 64]
# [datetime.datetime(2011, 12, 29, 0, 0), 3, 255, 69]
# [datetime.datetime(2011, 12, 30, 0, 0), 8, 263, 75]
# [datetime.datetime(2011, 12, 31, 0, 0), 6, 269, 81]
# [datetime.datetime(2012, 1, 1, 0, 0), 1, 1, 81]
# [datetime.datetime(2012, 1, 2, 0, 0), 1, 2, 81]
# [datetime.datetime(2012, 1, 3, 0, 0), 11, 13, 83]
# [datetime.datetime(2012, 1, 4, 0, 0), 5, 18, 84]
# [datetime.datetime(2012, 1, 5, 0, 0), 10, 28, 88]
# [datetime.datetime(2012, 1, 6, 0, 0), 10, 38, 97]
# [datetime.datetime(2012, 1, 8, 0, 0), 3, 41, 96]
# [datetime.datetime(2012, 1, 9, 0, 0), 1, 42, 94]
# [datetime.datetime(2012, 1, 10, 0, 0), 3, 45, 91]
# [datetime.datetime(2012, 1, 14, 0, 0), 7, 52, 94]
# [datetime.datetime(2012, 1, 15, 0, 0), 15, 67, 104]
# [datetime.datetime(2012, 1, 16, 0, 0), 2, 69, 106]
# [datetime.datetime(2012, 1, 17, 0, 0), 13, 82, 117]
# [datetime.datetime(2012, 1, 18, 0, 0), 8, 90, 115]
# [datetime.datetime(2012, 1, 19, 0, 0), 4, 94, 120]
# [datetime.datetime(2012, 1, 20, 0, 0), 3, 97, 118]
# [datetime.datetime(2012, 1, 21, 0, 0), 12, 109, 116]
# [datetime.datetime(2012, 1, 22, 0, 0), 7, 116, 117]
# [datetime.datetime(2012, 1, 23, 0, 0), 14, 130, 135]
# [datetime.datetime(2012, 1, 24, 0, 0), 1, 131, 130]
# [datetime.datetime(2012, 1, 25, 0, 0), 11, 142, 134]
# [datetime.datetime(2012, 1, 26, 0, 0), 13, 155, 143]
# [datetime.datetime(2012, 1, 27, 0, 0), 1, 156, 142]
# [datetime.datetime(2012, 1, 29, 0, 0), 3, 159, 141]
# [datetime.datetime(2012, 1, 30, 0, 0), 10, 169, 141]
# [datetime.datetime(2012, 1, 31, 0, 0), 8, 177, 144]
# [datetime.datetime(2012, 2, 1, 0, 0), 12, 189, 152]
# [datetime.datetime(2012, 2, 2, 0, 0), 3, 192, 150]
# [datetime.datetime(2012, 2, 9, 0, 0), 1, 193, 139]
# [datetime.datetime(2012, 2, 13, 0, 0), 1, 194, 130]
# [datetime.datetime(2012, 2, 14, 0, 0), 1, 195, 130]
# [datetime.datetime(2012, 2, 17, 0, 0), 3, 198, 131]
# [datetime.datetime(2012, 2, 18, 0, 0), 15, 213, 142]
# [datetime.datetime(2012, 2, 19, 0, 0), 17, 230, 158]
# [datetime.datetime(2012, 2, 20, 0, 0), 2, 232, 158]
# [datetime.datetime(2012, 2, 21, 0, 0), 3, 235, 156]
# [datetime.datetime(2012, 2, 22, 0, 0), 16, 251, 172]
# [datetime.datetime(2012, 2, 23, 0, 0), 6, 257, 172]
# [datetime.datetime(2012, 2, 24, 0, 0), 3, 260, 173]
# [datetime.datetime(2012, 2, 25, 0, 0), 18, 278, 193]
# [datetime.datetime(2012, 2, 26, 0, 0), 14, 292, 204]
# [datetime.datetime(2012, 2, 29, 0, 0), 10, 302, 191]
# [datetime.datetime(2012, 3, 1, 0, 0), 9, 311, 194]
# [datetime.datetime(2012, 3, 2, 0, 0), 4, 315, 190]
# [datetime.datetime(2012, 3, 3, 0, 0), 5, 320, 190]
# [datetime.datetime(2012, 3, 4, 0, 0), 3, 323, 190]
# [datetime.datetime(2012, 3, 5, 0, 0), 14, 337, 198]
# [datetime.datetime(2012, 3, 6, 0, 0), 14, 351, 210]
# [datetime.datetime(2012, 3, 10, 0, 0), 14, 365, 204]
# [datetime.datetime(2012, 3, 11, 0, 0), 20, 385, 224]
# [datetime.datetime(2012, 3, 12, 0, 0), 22, 407, 235]
# [datetime.datetime(2012, 3, 13, 0, 0), 13, 420, 236]
# [datetime.datetime(2012, 3, 14, 0, 0), 17, 437, 236]
# [datetime.datetime(2012, 3, 15, 0, 0), 22, 459, 236]
# [datetime.datetime(2012, 3, 16, 0, 0), 14, 473, 258]
# [datetime.datetime(2012, 3, 17, 0, 0), 6, 479, 258]
# [datetime.datetime(2012, 3, 18, 0, 0), 8, 487, 253]
# [datetime.datetime(2012, 3, 19, 0, 0), 8, 495, 254]
# [datetime.datetime(2012, 3, 20, 0, 0), 5, 500, 251]
# [datetime.datetime(2012, 3, 21, 0, 0), 12, 512, 251]
# [datetime.datetime(2012, 3, 27, 0, 0), 1, 513, 236]
# [datetime.datetime(2012, 3, 28, 0, 0), 1, 514, 235]
# [datetime.datetime(2012, 3, 29, 0, 0), 13, 527, 244]
# [datetime.datetime(2012, 3, 30, 0, 0), 18, 545, 259]
# [datetime.datetime(2012, 3, 31, 0, 0), 10, 555, 264]
# [datetime.datetime(2012, 4, 1, 0, 0), 8, 563, 267]
# [datetime.datetime(2012, 4, 2, 0, 0), 5, 568, 268]
# [datetime.datetime(2012, 4, 4, 0, 0), 6, 574, 259]
# [datetime.datetime(2012, 4, 5, 0, 0), 4, 578, 256]
# [datetime.datetime(2012, 4, 13, 0, 0), 1, 579, 232]
# [datetime.datetime(2012, 4, 20, 0, 0), 2, 581, 229]
# [datetime.datetime(2012, 4, 27, 0, 0), 1, 582, 205]
# [datetime.datetime(2012, 10, 23, 0, 0), 10, 592, 12]
# [datetime.datetime(2012, 11, 19, 0, 0), 14, 606, 12]
# [datetime.datetime(2012, 11, 20, 0, 0), 7, 613, 41]
# [datetime.datetime(2012, 11, 21, 0, 0), 7, 620, 40]
# [datetime.datetime(2012, 11, 23, 0, 0), 5, 625, 54]
# [datetime.datetime(2012, 11, 24, 0, 0), 4, 629, 52]
# [datetime.datetime(2012, 11, 30, 0, 0), 1, 630, 43]
# [datetime.datetime(2012, 12, 1, 0, 0), 9, 639, 51]
# [datetime.datetime(2012, 12, 3, 0, 0), 13, 652, 77]
# [datetime.datetime(2012, 12, 5, 0, 0), 5, 657, 76]
# [datetime.datetime(2012, 12, 6, 0, 0), 14, 671, 85]
# [datetime.datetime(2012, 12, 7, 0, 0), 21, 692, 102]
# [datetime.datetime(2012, 12, 8, 0, 0), 6, 698, 105]
# [datetime.datetime(2012, 12, 9, 0, 0), 3, 701, 105]
# [datetime.datetime(2012, 12, 10, 0, 0), 7, 708, 105]
# [datetime.datetime(2012, 12, 12, 0, 0), 6, 714, 105]
# [datetime.datetime(2012, 12, 14, 0, 0), 4, 718, 94]
# [datetime.datetime(2012, 12, 16, 0, 0), 20, 738, 108]
# [datetime.datetime(2012, 12, 17, 0, 0), 22, 760, 123]
# [datetime.datetime(2012, 12, 18, 0, 0), 16, 776, 132]
# [datetime.datetime(2012, 12, 19, 0, 0), 7, 783, 132]
# [datetime.datetime(2012, 12, 20, 0, 0), 19, 802, 140]
# [datetime.datetime(2012, 12, 22, 0, 0), 5, 807, 151]
# [datetime.datetime(2012, 12, 23, 0, 0), 10, 817, 147]
# [datetime.datetime(2012, 12, 24, 0, 0), 5, 822, 143]
# [datetime.datetime(2012, 12, 26, 0, 0), 4, 826, 137]
# [datetime.datetime(2012, 12, 28, 0, 0), 3, 829, 138]
# [datetime.datetime(2012, 12, 29, 0, 0), 3, 832, 136]
# [datetime.datetime(2012, 12, 30, 0, 0), 3, 835, 135]
# [datetime.datetime(2013, 1, 4, 0, 0), 3, 3, 129]
# [datetime.datetime(2013, 1, 5, 0, 0), 2, 5, 129]
# [datetime.datetime(2013, 1, 6, 0, 0), 10, 15, 135]
# [datetime.datetime(2013, 1, 7, 0, 0), 5, 20, 135]
# [datetime.datetime(2013, 1, 9, 0, 0), 10, 30, 135]
# [datetime.datetime(2013, 1, 10, 0, 0), 14, 44, 135]
# [datetime.datetime(2013, 1, 23, 0, 0), 3, 47, 132]
# [datetime.datetime(2013, 1, 24, 0, 0), 9, 56, 132]
# [datetime.datetime(2013, 1, 25, 0, 0), 6, 62, 142]
# [datetime.datetime(2013, 1, 26, 0, 0), 2, 64, 142]
# [datetime.datetime(2013, 1, 27, 0, 0), 10, 74, 147]
# [datetime.datetime(2013, 1, 28, 0, 0), 7, 81, 147]
# [datetime.datetime(2013, 1, 29, 0, 0), 9, 90, 150]
# [datetime.datetime(2013, 1, 30, 0, 0), 5, 95, 150]
# [datetime.datetime(2013, 1, 31, 0, 0), 2, 97, 150]
# [datetime.datetime(2013, 2, 4, 0, 0), 3, 100, 150]
# [datetime.datetime(2013, 2, 5, 0, 0), 3, 103, 152]
# [datetime.datetime(2013, 2, 6, 0, 0), 14, 117, 152]
# [datetime.datetime(2013, 2, 13, 0, 0), 4, 121, 160]
# [datetime.datetime(2013, 2, 14, 0, 0), 1, 122, 160]
# [datetime.datetime(2013, 2, 15, 0, 0), 2, 124, 160]
# [datetime.datetime(2013, 2, 16, 0, 0), 6, 130, 161]
# [datetime.datetime(2013, 2, 19, 0, 0), 2, 132, 158]
# [datetime.datetime(2013, 2, 21, 0, 0), 3, 135, 157]
# [datetime.datetime(2013, 2, 22, 0, 0), 10, 145, 157]
# [datetime.datetime(2013, 2, 23, 0, 0), 6, 151, 174]
# [datetime.datetime(2013, 2, 24, 0, 0), 2, 153, 175]
# [datetime.datetime(2013, 2, 25, 0, 0), 9, 162, 175]
# [datetime.datetime(2013, 2, 26, 0, 0), 18, 180, 192]
# [datetime.datetime(2013, 2, 27, 0, 0), 2, 182, 192]
# [datetime.datetime(2013, 2, 28, 0, 0), 2, 184, 192]
# [datetime.datetime(2013, 3, 1, 0, 0), 6, 190, 192]
# [datetime.datetime(2013, 3, 2, 0, 0), 3, 193, 183]
# [datetime.datetime(2013, 3, 12, 0, 0), 2, 195, 170]
# [datetime.datetime(2013, 3, 13, 0, 0), 6, 201, 170]
# [datetime.datetime(2013, 3, 15, 0, 0), 4, 205, 170]
# [datetime.datetime(2013, 3, 16, 0, 0), 3, 208, 175]
# [datetime.datetime(2013, 3, 17, 0, 0), 5, 213, 175]
# [datetime.datetime(2013, 3, 20, 0, 0), 13, 226, 202]
# [datetime.datetime(2013, 3, 21, 0, 0), 8, 234, 202]
# [datetime.datetime(2013, 3, 22, 0, 0), 5, 239, 202]
# [datetime.datetime(2013, 3, 23, 0, 0), 1, 240, 201]
# [datetime.datetime(2013, 4, 5, 0, 0), 2, 242, 170]
# [datetime.datetime(2013, 4, 6, 0, 0), 2, 244, 169]
# [datetime.datetime(2013, 4, 7, 0, 0), 12, 256, 181]
# [datetime.datetime(2013, 4, 8, 0, 0), 4, 260, 181]
# [datetime.datetime(2013, 4, 20, 0, 0), 2, 262, 177]
# [datetime.datetime(2013, 11, 16, 0, 0), 20, 282, 10]
# [datetime.datetime(2013, 11, 19, 0, 0), 10, 292, 14]
# [datetime.datetime(2013, 11, 30, 0, 0), 1, 293, 30]
# [datetime.datetime(2013, 12, 1, 0, 0), 1, 294, 29]
# [datetime.datetime(2013, 12, 2, 0, 0), 6, 300, 35]
# [datetime.datetime(2013, 12, 3, 0, 0), 6, 306, 40]
# [datetime.datetime(2013, 12, 4, 0, 0), 1, 307, 40]
# [datetime.datetime(2013, 12, 10, 0, 0), 2, 309, 38]
# [datetime.datetime(2013, 12, 11, 0, 0), 4, 313, 44]
# [datetime.datetime(2013, 12, 12, 0, 0), 4, 317, 44]
# [datetime.datetime(2013, 12, 13, 0, 0), 3, 320, 45]
# [datetime.datetime(2013, 12, 16, 0, 0), 3, 323, 43]
# [datetime.datetime(2013, 12, 17, 0, 0), 3, 326, 39]
# [datetime.datetime(2013, 12, 18, 0, 0), 2, 328, 39]
# [datetime.datetime(2013, 12, 20, 0, 0), 2, 330, 43]
# [datetime.datetime(2013, 12, 21, 0, 0), 9, 339, 45]
# [datetime.datetime(2013, 12, 22, 0, 0), 5, 344, 49]
# [datetime.datetime(2013, 12, 23, 0, 0), 1, 345, 50]
# [datetime.datetime(2013, 12, 24, 0, 0), 6, 351, 53]
# [datetime.datetime(2013, 12, 26, 0, 0), 1, 352, 52]
# [datetime.datetime(2013, 12, 28, 0, 0), 1, 353, 55]
# [datetime.datetime(2014, 1, 1, 0, 0), 1, 1, 51]
# [datetime.datetime(2014, 1, 2, 0, 0), 1, 2, 53]
# [datetime.datetime(2014, 1, 3, 0, 0), 11, 13, 62]
# [datetime.datetime(2014, 1, 4, 0, 0), 12, 25, 60]
# [datetime.datetime(2014, 1, 5, 0, 0), 1, 26, 61]
# [datetime.datetime(2014, 1, 8, 0, 0), 2, 28, 57]
# [datetime.datetime(2014, 1, 9, 0, 0), 19, 47, 76]
# [datetime.datetime(2014, 1, 10, 0, 0), 5, 52, 76]
# [datetime.datetime(2014, 1, 11, 0, 0), 8, 60, 85]
# [datetime.datetime(2014, 1, 12, 0, 0), 11, 71, 93]
# [datetime.datetime(2014, 1, 13, 0, 0), 4, 75, 90]
# [datetime.datetime(2014, 1, 14, 0, 0), 1, 76, 90]
# [datetime.datetime(2014, 1, 30, 0, 0), 1, 77, 74]
# [datetime.datetime(2014, 1, 31, 0, 0), 8, 85, 81]
# [datetime.datetime(2014, 2, 10, 0, 0), 4, 89, 84]
# [datetime.datetime(2014, 2, 11, 0, 0), 17, 106, 95]
# [datetime.datetime(2014, 2, 12, 0, 0), 13, 119, 101]
# [datetime.datetime(2014, 2, 13, 0, 0), 10, 129, 102]
# [datetime.datetime(2014, 2, 14, 0, 0), 18, 147, 104]
# [datetime.datetime(2014, 2, 15, 0, 0), 13, 160, 104]
# [datetime.datetime(2014, 2, 16, 0, 0), 12, 172, 116]
# [datetime.datetime(2014, 2, 17, 0, 0), 17, 189, 127]
# [datetime.datetime(2014, 2, 18, 0, 0), 13, 202, 135]
# [datetime.datetime(2014, 2, 19, 0, 0), 15, 217, 143]
# [datetime.datetime(2014, 2, 20, 0, 0), 6, 223, 144]
# [datetime.datetime(2014, 2, 21, 0, 0), 16, 239, 145]
# [datetime.datetime(2014, 2, 22, 0, 0), 10, 249, 145]
# [datetime.datetime(2014, 2, 23, 0, 0), 8, 257, 147]
# [datetime.datetime(2014, 2, 24, 0, 0), 10, 267, 151]
# [datetime.datetime(2014, 2, 25, 0, 0), 5, 272, 148]
# [datetime.datetime(2014, 2, 28, 0, 0), 8, 280, 135]
# [datetime.datetime(2014, 3, 1, 0, 0), 8, 288, 133]
# [datetime.datetime(2014, 3, 2, 0, 0), 7, 295, 135]
# [datetime.datetime(2014, 3, 3, 0, 0), 23, 318, 152]
# [datetime.datetime(2014, 3, 4, 0, 0), 13, 331, 167]
# [datetime.datetime(2014, 3, 5, 0, 0), 6, 337, 162]
# [datetime.datetime(2014, 3, 6, 0, 0), 9, 346, 157]
# [datetime.datetime(2014, 3, 7, 0, 0), 7, 353, 159]
# [datetime.datetime(2014, 3, 8, 0, 0), 2, 355, 156]
# [datetime.datetime(2014, 3, 10, 0, 0), 2, 357, 150]
# [datetime.datetime(2014, 3, 13, 0, 0), 4, 361, 139]
# [datetime.datetime(2014, 3, 14, 0, 0), 9, 370, 139]
# [datetime.datetime(2014, 3, 15, 0, 0), 8, 378, 142]
# [datetime.datetime(2014, 3, 16, 0, 0), 6, 384, 143]
# [datetime.datetime(2014, 3, 17, 0, 0), 12, 396, 157]
# [datetime.datetime(2014, 3, 18, 0, 0), 1, 397, 152]
# [datetime.datetime(2014, 3, 19, 0, 0), 3, 400, 150]
# [datetime.datetime(2014, 3, 20, 0, 0), 7, 407, 165]
# [datetime.datetime(2014, 3, 21, 0, 0), 3, 410, 164]
# [datetime.datetime(2014, 3, 22, 0, 0), 2, 412, 164]
# [datetime.datetime(2014, 3, 26, 0, 0), 12, 424, 162]
# [datetime.datetime(2014, 3, 27, 0, 0), 10, 434, 160]
# [datetime.datetime(2014, 3, 28, 0, 0), 23, 457, 153]
# [datetime.datetime(2014, 3, 29, 0, 0), 19, 476, 161]
# [datetime.datetime(2014, 3, 30, 0, 0), 8, 484, 175]
# [datetime.datetime(2014, 3, 31, 0, 0), 26, 510, 177]
# [datetime.datetime(2014, 4, 3, 0, 0), 16, 526, 163]
# [datetime.datetime(2014, 4, 4, 0, 0), 20, 546, 174]
# [datetime.datetime(2014, 4, 5, 0, 0), 6, 552, 170]
# [datetime.datetime(2014, 4, 6, 0, 0), 4, 556, 174]
# [datetime.datetime(2014, 4, 17, 0, 0), 8, 564, 151]
# [datetime.datetime(2014, 4, 18, 0, 0), 2, 566, 151]
# [datetime.datetime(2014, 4, 19, 0, 0), 2, 568, 154]
# [datetime.datetime(2014, 4, 20, 0, 0), 2, 570, 160]
# [datetime.datetime(2014, 11, 25, 0, 0), 8, 578, 28]
# [datetime.datetime(2014, 12, 19, 0, 0), 7, 585, 21]
# [datetime.datetime(2014, 12, 21, 0, 0), 2, 587, 32]
# [datetime.datetime(2014, 12, 23, 0, 0), 12, 599, 26]
# [datetime.datetime(2014, 12, 24, 0, 0), 10, 609, 37]
# [datetime.datetime(2014, 12, 26, 0, 0), 2, 611, 37]
# [datetime.datetime(2014, 12, 27, 0, 0), 14, 625, 35]
# [datetime.datetime(2014, 12, 28, 0, 0), 5, 630, 46]
# [datetime.datetime(2015, 1, 2, 0, 0), 3, 3, 40]
# [datetime.datetime(2015, 1, 3, 0, 0), 3, 6, 40]
# [datetime.datetime(2015, 1, 4, 0, 0), 15, 21, 40]
# [datetime.datetime(2015, 1, 5, 0, 0), 12, 33, 55]
# [datetime.datetime(2015, 1, 16, 0, 0), 3, 36, 43]
# [datetime.datetime(2015, 1, 17, 0, 0), 1, 37, 47]
# [datetime.datetime(2015, 1, 18, 0, 0), 15, 52, 46]
# [datetime.datetime(2015, 2, 2, 0, 0), 1, 53, 37]
# [datetime.datetime(2015, 2, 3, 0, 0), 3, 56, 38]
# [datetime.datetime(2015, 2, 7, 0, 0), 4, 60, 31]
# [datetime.datetime(2015, 2, 8, 0, 0), 2, 62, 32]
# [datetime.datetime(2015, 2, 26, 0, 0), 1, 63, 23]
# [datetime.datetime(2015, 3, 2, 0, 0), 1, 64, 21]
# [datetime.datetime(2015, 3, 24, 0, 0), 4, 68, 21]
# [datetime.datetime(2015, 11, 17, 0, 0), 15, 83, 43]
# [datetime.datetime(2015, 11, 18, 0, 0), 2, 85, 37]
# [datetime.datetime(2015, 11, 19, 0, 0), 1, 86, 35]
# [datetime.datetime(2015, 11, 24, 0, 0), 4, 90, 35]

# %% [markdown]
# ## Time to store data
#
# Schema:
# * date
# * resort (whistler/baker)
# * 24snowfall
# * basedepth
#
# Ignore total seasonal snowfall (position 3 of 4)

# %%
# import psycopg2

# %%
# conn = psycopg2.connect("dbname=border")

# %%
# cur = conn.cursor()

# %%
# for i, resort in enumerate(['baker', 'whistler']):
#     for day in data[i]:
#         cur.execute("INSERT INTO skiconditions (date, resort, snow24, basedepth) VALUES (%s, %s, %s, %s)",\
#             (convert_date(day[0]), resort, in_to_int(day[1]), in_to_int(day[3])))
        
#         conn.commit()

# %%
# cur.close()
# conn.close()

# %% [markdown]
# ## Switch to MySQL
# Much better admin tools

# %%
import mysql.connector

# %%
conn = mysql.connector.connect(user='dev', password='dev', host='localhost', database='border')

# %%
cur = conn.cursor()

for i, resort in enumerate(['baker', 'whistler']):
    for day in data[i]:
        cur.execute("INSERT INTO skiconditions (date, resort, snow24, basedepth) VALUES (%s, %s, %s, %s)",\
            (convert_date(day[0]), resort, in_to_int(day[1]), in_to_int(day[3])))
        
conn.commit()

cur.close()
conn.close()
